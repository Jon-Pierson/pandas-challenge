# %%
# Dependencies: pandas, numpy, pathlib
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# Define the path schools_complete.csv and ensure the path is correct
school_data_path = Path('Resources/schools_complete.csv')
print(school_data_path.exists())
# Out:
# True

# %%
# Define the path students_complete.csv and ensure the path is correct
student_data_path = Path('Resources/students_complete.csv')
print(student_data_path.exists())
# Out:
# True

# %%
# Read data files and store in pandas DataFrames
school_data = pd.read_csv(school_data_path)
student_data = pd.read_csv(student_data_path)

# %%
# Display the first 5 rows of the school_data DataFrame
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
# Display the first 5 rows of the student_data DataFrame
student_data.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# Combine the data into a single DataFrame using a left join on the school_name column
school_data_left_join = pd.merge(student_data, school_data, how='left', on=['school_name', 'school_name'])
school_data_left_join.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
# Combine the data into a single DataFrame using a right join on the school_name column
school_data_right_join = pd.merge(student_data, school_data, how='right', on=['school_name', 'school_name'])
school_data_right_join.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
# Display school_data_left_join DataFrame information
school_data_left_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39170 entries, 0 to 39169
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student ID     39170 non-null  int64
#  1   student_name   39170 non-null  object
#  2   gender         39170 non-null  object
#  3   grade          39170 non-null  object
#  4   school_name    39170 non-null  object
#  5   reading_score  39170 non-null  int64
#  6   math_score     39170 non-null  int64
#  7   School ID      39170 non-null  int64
#  8   type           39170 non-null  object
#  9   size           39170 non-null  int64
#  10  budget         39170 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 3.3+ MB

# %%
# Display school_data_right_join DataFrame information
school_data_right_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39170 entries, 0 to 39169
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student ID     39170 non-null  int64
#  1   student_name   39170 non-null  object
#  2   gender         39170 non-null  object
#  3   grade          39170 non-null  object
#  4   school_name    39170 non-null  object
#  5   reading_score  39170 non-null  int64
#  6   math_score     39170 non-null  int64
#  7   School ID      39170 non-null  int64
#  8   type           39170 non-null  object
#  9   size           39170 non-null  int64
#  10  budget         39170 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 3.3+ MB

# %%
# Using the school_data_left_join DataFrame, calculate the total number of schools
total_schools = school_data_left_join['school_name'].nunique()
total_schools
# Out:
# 15

# %%
# Using the school_data_left_join DataFrame, calculate the total number of students
total_students = school_data_left_join['student_name'].count()
total_students
# Out:
# 39170

# %%
# Using the school_data_left_join DataFrame, calculate the total budget
total_budget = school_data_left_join['budget'].unique().sum()
total_budget
# Out:
# 24649428

# %%
# Using the school_data_left_join DataFrame, calculate the average math score
average_math_score = school_data_left_join['math_score'].mean()
average_math_score
# Out:
# 78.98537145774827

# %%
# Using the school_data_left_join DataFrame, calculate the average reading score
average_reading_score = school_data_left_join['reading_score'].mean()
average_reading_score
# Out:
# 81.87784018381414

# %%
# Using the school_data_left_join DataFrame, calculate the percentage of students with a passing math score (70 or greater)
passing_math_score = school_data_left_join[school_data_left_join['math_score'] >= 70]['math_score'].count()
percentage_passing_math_score = (passing_math_score / total_students) * 100
percentage_passing_math_score
# Out:
# 74.9808526933878

# %%
# Using the school_data_left_join DataFrame, calculate the percentage of students with a passing reading score (70 or greater)
passing_reading_score = school_data_left_join[school_data_left_join['reading_score'] >= 70]['reading_score'].count()
percentage_passing_reading_score = (passing_reading_score / total_students) * 100
percentage_passing_reading_score
# Out:
# 85.80546336482001

# %%
# Using the school_data_left_join DataFrame, calculate the percentage of students who passed math and reading (% Overall Passing)
overall_passing_score = school_data_left_join[(school_data_left_join['math_score'] >= 70) & (school_data_left_join['reading_score'] >= 70)]['student_name'].count()
percentage_overall_passing_score = (overall_passing_score / total_students) * 100
percentage_overall_passing_score
# Out:
# 65.17232575950983

# %%
# Create a DataFrame to hold the above results and format the data
district_summary = pd.DataFrame({
    'Total Schools': [total_schools],
    'Total Students': [total_students],
    'Total Budget': [total_budget],
    'Average Math Score': [average_math_score],
    'Average Reading Score': [average_reading_score],
    '% Passing Math': [percentage_passing_math_score],
    '% Passing Reading': [percentage_passing_reading_score],
    '% Overall Passing': [percentage_overall_passing_score]
})
district_summary['Total Students'] = district_summary['Total Students'].map('{:,}'.format)
district_summary['Total Budget'] = district_summary['Total Budget'].map('${:,.2f}'.format)
district_summary['Average Math Score'] = district_summary['Average Math Score'].map('{:.2f}%'.format)
district_summary['Average Reading Score'] = district_summary['Average Reading Score'].map('{:.2f}%'.format)
district_summary['% Passing Math'] = district_summary['% Passing Math'].map('{:.2f}%'.format)
district_summary['% Passing Reading'] = district_summary['% Passing Reading'].map('{:.2f}%'.format)
district_summary['% Overall Passing'] = district_summary['% Overall Passing'].map('{:.2f}%'.format)
district_summary
# Out:
#    Total Schools Total Students    Total Budget Average Math Score  \
# 0             15         39,170  $24,649,428.00             78.99%
#
#   Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                81.88%         74.98%            85.81%            65.17%

# %%
import os

# Define the home directory
home_dir = os.getcwd()

# Define the subdirectory to save the output file
analysis_dir = os.path.join(home_dir, "analysis")

# Ensure the directory exists before writing the output file
if os.path.exists(analysis_dir) and os.path.isdir(analysis_dir):
    print(f"Directory exists: {analysis_dir}")
else:
    print(f"Directory does not exist: {analysis_dir}")
# Out:
# Directory exists: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis

# %%
# Define the name of the output file
output_file_ds = "district_summary.csv"

# Combine the directory and file name to create the full path
output_file_path_ds = os.path.join(analysis_dir, output_file_ds)

# Display the full output file path
print(f"Output file path: {output_file_path_ds}")
# Out:
# Output file path: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis\district_summary.csv

# %%
# Save the district summary DataFrame to a CSV file
district_summary.to_csv(output_file_path_ds, index=False)

# Ensure the output file was created
if os.path.exists(output_file_path_ds) and os.path.isfile(output_file_path_ds):
    print(f"Output file created: {output_file_path_ds}")
# Out:
# Output file created: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis\district_summary.csv

# %%
# Using the school_data_left_join DataFrame, display the unique school names and sort the names in ascending order
school_names = school_data_left_join['school_name'].unique()
school_names.sort()
school_names
# Out:
# array(['Bailey High School', 'Cabrera High School',
#        'Figueroa High School', 'Ford High School', 'Griffin High School',
#        'Hernandez High School', 'Holden High School', 'Huang High School',
#        'Johnson High School', 'Pena High School', 'Rodriguez High School',
#        'Shelton High School', 'Thomas High School', 'Wilson High School',
#        'Wright High School'], dtype=object)

# %%
# Using the school_data_left_join DataFrame, calculate the total number of students at each school
total_students_per_school = school_data_left_join['school_name'].value_counts()
total_students_per_school
# Out:
# school_name
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: count, dtype: int64

# %%
# Using the school_data_left_join DataFrame, calculate the total budget at each school
total_budget_per_school = school_data_left_join.groupby('school_name')['budget'].mean()
total_budget_per_school
# Out:
# school_name
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# Name: budget, dtype: float64

# %%
# Using the school_data_left_join DataFrame, calculate the budget per student at each school
budget_per_student = total_budget_per_school / total_students_per_school
budget_per_student
# Out:
# school_name
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
# Using the school_data_left_join DataFrame, calculate the average math score at each school
average_math_score_per_school = school_data_left_join.groupby('school_name')['math_score'].mean()
average_math_score_per_school
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
# Using the school_data_left_join DataFrame, calculate the average reading score at each school
average_reading_score_per_school = school_data_left_join.groupby('school_name')['reading_score'].mean()
average_reading_score_per_school
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
# Using the school_data_left_join DataFrame, calculate the percentage of students with a passing math score (70 or greater) at each school
passing_math_score_per_school = school_data_left_join[school_data_left_join['math_score'] >= 70].groupby('school_name')['math_score'].count()
percentage_passing_math_score_per_school = (passing_math_score_per_school / total_students_per_school) * 100
percentage_passing_math_score_per_school
# Out:
# school_name
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# dtype: float64

# %%
# Using the school_data_left_join DataFrame, calculate the percentage of students with a passing reading score (70 or greater) at each school
passing_reading_score_per_school = school_data_left_join[school_data_left_join['reading_score'] >= 70].groupby('school_name')['reading_score'].count()
percentage_passing_reading_score_per_school = (passing_reading_score_per_school / total_students_per_school) * 100
percentage_passing_reading_score_per_school
# Out:
# school_name
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# dtype: float64

# %%
# Using the school_data_left_join DataFrame, calculate the percentage of students who passed math and reading (% Overall Passing) at each school
overall_passing_score_per_school = school_data_left_join[(school_data_left_join['math_score'] >= 70) & (school_data_left_join['reading_score'] >= 70)].groupby('school_name')['student_name'].count()
percentage_overall_passing_score_per_school = (overall_passing_score_per_school / total_students_per_school) * 100
percentage_overall_passing_score_per_school
# Out:
# school_name
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       90.948012
# Wilson High School       90.582567
# Wright High School       90.333333
# dtype: float64

# %%
# Create a DataFrame to hold the above results and format the data indexing by school_name and format the data
school_summary = pd.DataFrame({
    'School Name' : school_names,
    'Total Students': total_students_per_school,
    'Total School Budget': total_budget_per_school,
    'Per Student Budget': budget_per_student,
    'Average Math Score': average_math_score_per_school,
    'Average Reading Score': average_reading_score_per_school,
    '% Passing Math': percentage_passing_math_score_per_school,
    '% Passing Reading': percentage_passing_reading_score_per_school,
    '% Overall Passing': percentage_overall_passing_score_per_school
})
school_summary['Total School Budget'] = school_summary['Total School Budget'].map('${:,.2f}'.format)
school_summary['Per Student Budget'] = school_summary['Per Student Budget'].map('${:,.2f}'.format)
school_summary['Average Math Score'] = school_summary['Average Math Score'].map('{:.2f}%'.format)
school_summary['Average Reading Score'] = school_summary['Average Reading Score'].map('{:.2f}%'.format)
school_summary['% Passing Math'] = school_summary['% Passing Math'].map('{:.2f}%'.format)
school_summary['% Passing Reading'] = school_summary['% Passing Reading'].map('{:.2f}%'.format)
school_summary['% Overall Passing'] = school_summary['% Overall Passing'].map('{:.2f}%'.format)
school_summary
# Out:
#                                  School Name  Total Students  \
# school_name
# Bailey High School        Bailey High School            4976
# Cabrera High School      Cabrera High School            1858
# Figueroa High School    Figueroa High School            2949
# Ford High School            Ford High School            2739
# Griffin High School      Griffin High School            1468
# Hernandez High School  Hernandez High School            4635
# Holden High School        Holden High School             427
# Huang High School          Huang High School            2917
# Johnson High School      Johnson High School            4761
# Pena High School            Pena High School             962
# Rodriguez High School  Rodriguez High School            3999
# Shelton High School      Shelton High School            1761
# Thomas High School        Thomas High School            1635
# Wilson High School        Wilson High School            2283
# Wright High School        Wright High School            1800
#
#                       Total School Budget Per Student Budget  \
# school_name
# Bailey High School          $3,124,928.00            $628.00
# Cabrera High School         $1,081,356.00            $582.00
# Figueroa High School        $1,884,411.00            $639.00
# Ford High School            $1,763,916.00            $644.00
# Griffin High School           $917,500.00            $625.00
# Hernandez High School       $3,022,020.00            $652.00
# Holden High School            $248,087.00            $581.00
# Huang High School           $1,910,635.00            $655.00
# Johnson High School         $3,094,650.00            $650.00
# Pena High School              $585,858.00            $609.00
# Rodriguez High School       $2,547,363.00            $637.00
# Shelton High School         $1,056,600.00            $600.00
# Thomas High School          $1,043,130.00            $638.00
# Wilson High School          $1,319,574.00            $578.00
# Wright High School          $1,049,400.00            $583.00
#
#                       Average Math Score Average Reading Score % Passing Math  \
# school_name
# Bailey High School                77.05%                81.03%         66.68%
# Cabrera High School               83.06%                83.98%         94.13%
# Figueroa High School              76.71%                81.16%         65.99%
# Ford High School                  77.10%                80.75%         68.31%
# Griffin High School               83.35%                83.82%         93.39%
# Hernandez High School             77.29%                80.93%         66.75%
# Holden High School                83.80%                83.81%         92.51%
# Huang High School                 76.63%                81.18%         65.68%
# Johnson High School               77.07%                80.97%         66.06%
# Pena High School                  83.84%                84.04%         94.59%
# Rodriguez High School             76.84%                80.74%         66.37%
# Shelton High School               83.36%                83.73%         93.87%
# Thomas High School                83.42%                83.85%         93.27%
# Wilson High School                83.27%                83.99%         93.87%
# Wright High School                83.68%                83.95%         93.33%
#
#                       % Passing Reading % Overall Passing
# school_name
# Bailey High School               81.93%            54.64%
# Cabrera High School              97.04%            91.33%
# Figueroa High School             80.74%            53.20%
# Ford High School                 79.30%            54.29%
# Griffin High School              97.14%            90.60%
# Hernandez High School            80.86%            53.53%
# Holden High School               96.25%            89.23%
# Huang High School                81.32%            53.51%
# Johnson High School              81.22%            53.54%
# Pena High School                 95.95%            90.54%
# Rodriguez High School            80.22%            52.99%
# Shelton High School              95.85%            89.89%
# Thomas High School               97.31%            90.95%
# Wilson High School               96.54%            90.58%
# Wright High School               96.61%            90.33%

# %%
import os

# Define the home directory
home_dir = os.getcwd()

# Define the subdirectory to save the output file
analysis_dir = os.path.join(home_dir, "analysis")

# Ensure the directory exists before writing the output file
if os.path.exists(analysis_dir) and os.path.isdir(analysis_dir):
    print(f"Directory exists: {analysis_dir}")
else:
    print(f"Directory does not exist: {analysis_dir}")
# Out:
# Directory exists: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis

# %%
# Define the name of the output file
output_file_ss = "school_summary.csv"

# Combine the directory and file name to create the full path
output_file_path_ss = os.path.join(analysis_dir, output_file_ss)

# Display the full output file path
print(f"Output file path: {output_file_path_ss}")
# Out:
# Output file path: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis\school_summary.csv

# %%
# Save the schoool summary DataFrame to a CSV file
school_summary.to_csv(output_file_path_ss, index=False)

# Ensure the output file was created
if os.path.exists(output_file_path_ss) and os.path.isfile(output_file_path_ss):
    print(f"Output file created: {output_file_path_ss}")
# Out:
# Output file created: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis\school_summary.csv

# %%
# Create new DataFrame for the top 5 performing schools based on % Overall Passing
top_schools = school_summary.sort_values('% Overall Passing', ascending=False).head(5)
top_schools
# Out:
#                              School Name  Total Students Total School Budget  \
# school_name
# Cabrera High School  Cabrera High School            1858       $1,081,356.00
# Thomas High School    Thomas High School            1635       $1,043,130.00
# Griffin High School  Griffin High School            1468         $917,500.00
# Wilson High School    Wilson High School            2283       $1,319,574.00
# Pena High School        Pena High School             962         $585,858.00
#
#                     Per Student Budget Average Math Score  \
# school_name
# Cabrera High School            $582.00             83.06%
# Thomas High School             $638.00             83.42%
# Griffin High School            $625.00             83.35%
# Wilson High School             $578.00             83.27%
# Pena High School               $609.00             83.84%
#
#                     Average Reading Score % Passing Math % Passing Reading  \
# school_name
# Cabrera High School                83.98%         94.13%            97.04%
# Thomas High School                 83.85%         93.27%            97.31%
# Griffin High School                83.82%         93.39%            97.14%
# Wilson High School                 83.99%         93.87%            96.54%
# Pena High School                   84.04%         94.59%            95.95%
#
#                     % Overall Passing
# school_name
# Cabrera High School            91.33%
# Thomas High School             90.95%
# Griffin High School            90.60%
# Wilson High School             90.58%
# Pena High School               90.54%

# %%
import os

# Define the home directory
home_dir = os.getcwd()

# Define the subdirectory to save the output file
analysis_dir = os.path.join(home_dir, "analysis")

# Ensure the directory exists before writing the output file
if os.path.exists(analysis_dir) and os.path.isdir(analysis_dir):
    print(f"Directory exists: {analysis_dir}")
else:
    print(f"Directory does not exist: {analysis_dir}")
# Out:
# Directory exists: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis

# %%
# Define the name of the output file
output_file_ts = "top_schools.csv"

# Combine the directory and file name to create the full path
output_file_path_ts = os.path.join(analysis_dir, output_file_ts)

# Display the full output file path
print(f"Output file path: {output_file_path_ts}")
# Out:
# Output file path: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis\top_schools.csv

# %%
# Save the top schools DataFrame to a CSV file
top_schools.to_csv(output_file_path_ts, index=False)

# Ensure the output file was created
if os.path.exists(output_file_path_ts) and os.path.isfile(output_file_path_ts):
    print(f"Output file created: {output_file_path_ts}")
# Out:
# Output file created: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis\top_schools.csv

# %%
# Create new DataFrame for the bottom 5 performing schools based on % Overall Passing
bottom_schools = school_summary.sort_values('% Overall Passing', ascending=True).head(5)
bottom_schools
# Out:
#                                  School Name  Total Students  \
# school_name
# Rodriguez High School  Rodriguez High School            3999
# Figueroa High School    Figueroa High School            2949
# Huang High School          Huang High School            2917
# Hernandez High School  Hernandez High School            4635
# Johnson High School      Johnson High School            4761
#
#                       Total School Budget Per Student Budget  \
# school_name
# Rodriguez High School       $2,547,363.00            $637.00
# Figueroa High School        $1,884,411.00            $639.00
# Huang High School           $1,910,635.00            $655.00
# Hernandez High School       $3,022,020.00            $652.00
# Johnson High School         $3,094,650.00            $650.00
#
#                       Average Math Score Average Reading Score % Passing Math  \
# school_name
# Rodriguez High School             76.84%                80.74%         66.37%
# Figueroa High School              76.71%                81.16%         65.99%
# Huang High School                 76.63%                81.18%         65.68%
# Hernandez High School             77.29%                80.93%         66.75%
# Johnson High School               77.07%                80.97%         66.06%
#
#                       % Passing Reading % Overall Passing
# school_name
# Rodriguez High School            80.22%            52.99%
# Figueroa High School             80.74%            53.20%
# Huang High School                81.32%            53.51%
# Hernandez High School            80.86%            53.53%
# Johnson High School              81.22%            53.54%

# %%
import os

# Define the home directory
home_dir = os.getcwd()

# Define the subdirectory to save the output file
analysis_dir = os.path.join(home_dir, "analysis")

# Ensure the directory exists before writing the output file
if os.path.exists(analysis_dir) and os.path.isdir(analysis_dir):
    print(f"Directory exists: {analysis_dir}")
else:
    print(f"Directory does not exist: {analysis_dir}")
# Out:
# Directory exists: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis

# %%
# Define the name of the output file
output_file_bs = "bottom_schools.csv"

# Combine the directory and file name to create the full path
output_file_path_bs = os.path.join(analysis_dir, output_file_bs)

# Display the full output file path
print(f"Output file path: {output_file_path_bs}")
# Out:
# Output file path: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis\bottom_schools.csv

# %%
# Save the bottom schools DataFrame to a CSV file
bottom_schools.to_csv(output_file_path_bs, index=False)

# Ensure the output file was created
if os.path.exists(output_file_path_bs) and os.path.isfile(output_file_path_bs):
    print(f"Output file created: {output_file_path_bs}")
# Out:
# Output file created: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis\bottom_schools.csv

# %%
# Create a new DataFrame for grade level analysis
grade_level_analysis = school_data_left_join.groupby(['grade'])[['math_score', 'reading_score']].mean()
grade_level_analysis['math_score'] = grade_level_analysis['math_score'].map('{:.2f}%'.format)
grade_level_analysis['reading_score'] = grade_level_analysis['reading_score'].map('{:.2f}%'.format)
grade_level_analysis
# Out:
#       math_score reading_score
# grade
# 10th      78.94%        81.87%
# 11th      79.08%        81.89%
# 12th      78.99%        81.82%
# 9th       78.94%        81.91%

# %%
# Change the values of 'Grade' from '9th' to '9', '10th' to '10', '11th' to '11', and '12th' to '12'
grade_level_analysis.index = grade_level_analysis.index.str.replace('th', '')

# Change 'grade' data type to integer
grade_level_analysis.index = grade_level_analysis.index.astype(int)

# Sort the DataFrame by the index (grade)
grade_level_analysis = grade_level_analysis.sort_index()
grade_level_analysis
# Out:
#       math_score reading_score
# grade
# 9         78.94%        81.91%
# 10        78.94%        81.87%
# 11        79.08%        81.89%
# 12        78.99%        81.82%

# %%
# Create a series for the Grade column in the grade_level_analysis DataFrame
grade_series = grade_level_analysis.index

# Insert the Grade series into the grade_level_analysis DataFrame as a new column
grade_level_analysis.insert(0, 'Grade', grade_series)
grade_level_analysis

# Rename the columns in the grade_level_analysis DataFrame
grade_level_analysis = grade_level_analysis.rename(columns={
    'math_score': 'Average Math Score',
    'reading_score': 'Average Reading Score'
})
grade_level_analysis
# Out:
#        Grade Average Math Score Average Reading Score
# grade
# 9          9             78.94%                81.91%
# 10        10             78.94%                81.87%
# 11        11             79.08%                81.89%
# 12        12             78.99%                81.82%

# %%
import os

# Define the home directory
home_dir = os.getcwd()

# Define the subdirectory to save the output file
analysis_dir = os.path.join(home_dir, "analysis")

# Ensure the directory exists before writing the output file
if os.path.exists(analysis_dir) and os.path.isdir(analysis_dir):
    print(f"Directory exists: {analysis_dir}")
else:
    print(f"Directory does not exist: {analysis_dir}")
# Out:
# Directory exists: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis

# %%
# Define the name of the output file
output_file_gla = "grade_level_analysis.csv"

# Combine the directory and file name to create the full path
output_file_path_gla = os.path.join(analysis_dir, output_file_gla)

# Display the full output file path
print(f"Output file path: {output_file_path_gla}")
# Out:
# Output file path: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis\grade_level_analysis.csv

# %%
# Save the grade level analysis DataFrame to a CSV file
grade_level_analysis.to_csv(output_file_path_gla, index=False)

# Ensure the output file was created
if os.path.exists(output_file_path_gla) and os.path.isfile(output_file_path_gla):
    print(f"Output file created: {output_file_path_gla}")
# Out:
# Output file created: c:\Users\Jon\OneDrive\githubRepo\pandas-challenge\PyCitySchools\analysis\grade_level_analysis.csv

# %%
# Create a new DataFrame from the school_data_left_join DataFrame for school spending analysis (Delete: Student ID, student_name gender, grade, reading_score, math_score, budget, School ID columns)
cleaned_school_data = school_data_left_join.drop(columns=['Student ID', 'student_name', 'gender', 'grade', 'reading_score', 'math_score', 'budget', 'School ID'])

# Delete duplicate rows in the cleaned_school_data DataFrame
cleaned_school_data = cleaned_school_data.drop_duplicates()
cleaned_school_data
# Out:
#                  school_name      type  size
# 0          Huang High School  District  2917
# 2917    Figueroa High School  District  2949
# 5866     Shelton High School   Charter  1761
# 7627   Hernandez High School  District  4635
# 12262    Griffin High School   Charter  1468
# 13730     Wilson High School   Charter  2283
# 16013    Cabrera High School   Charter  1858
# 17871     Bailey High School  District  4976
# 22847     Holden High School   Charter   427
# 23274       Pena High School   Charter   962
# 24236     Wright High School   Charter  1800
# 26036  Rodriguez High School  District  3999
# 30035    Johnson High School  District  4761
# 34796       Ford High School  District  2739
# 37535     Thomas High School   Charter  1635

# %%
# Create a new DataFrame from the cleaned_school_data and school_summary DataFrames for "Scores by"analysis
scores_by_analysis = pd.merge(cleaned_school_data, school_summary, how='left', on=['school_name', 'school_name'])
scores_by_analysis
# Out:
#               school_name      type  size            School Name  \
# 0       Huang High School  District  2917      Huang High School
# 1    Figueroa High School  District  2949   Figueroa High School
# 2     Shelton High School   Charter  1761    Shelton High School
# 3   Hernandez High School  District  4635  Hernandez High School
# 4     Griffin High School   Charter  1468    Griffin High School
# 5      Wilson High School   Charter  2283     Wilson High School
# 6     Cabrera High School   Charter  1858    Cabrera High School
# 7      Bailey High School  District  4976     Bailey High School
# 8      Holden High School   Charter   427     Holden High School
# 9        Pena High School   Charter   962       Pena High School
# 10     Wright High School   Charter  1800     Wright High School
# 11  Rodriguez High School  District  3999  Rodriguez High School
# 12    Johnson High School  District  4761    Johnson High School
# 13       Ford High School  District  2739       Ford High School
# 14     Thomas High School   Charter  1635     Thomas High School
#
#     Total Students Total School Budget Per Student Budget Average Math Score  \
# 0             2917       $1,910,635.00            $655.00             76.63%
# 1             2949       $1,884,411.00            $639.00             76.71%
# 2             1761       $1,056,600.00            $600.00             83.36%
# 3             4635       $3,022,020.00            $652.00             77.29%
# 4             1468         $917,500.00            $625.00             83.35%
# 5             2283       $1,319,574.00            $578.00             83.27%
# 6             1858       $1,081,356.00            $582.00             83.06%
# 7             4976       $3,124,928.00            $628.00             77.05%
# 8              427         $248,087.00            $581.00             83.80%
# 9              962         $585,858.00            $609.00             83.84%
# 10            1800       $1,049,400.00            $583.00             83.68%
# 11            3999       $2,547,363.00            $637.00             76.84%
# 12            4761       $3,094,650.00            $650.00             77.07%
# 13            2739       $1,763,916.00            $644.00             77.10%
# 14            1635       $1,043,130.00            $638.00             83.42%
#
#    Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                 81.18%         65.68%            81.32%            53.51%
# 1                 81.16%         65.99%            80.74%            53.20%
# 2                 83.73%         93.87%            95.85%            89.89%
# 3                 80.93%         66.75%            80.86%            53.53%
# 4                 83.82%         93.39%            97.14%            90.60%
# 5                 83.99%         93.87%            96.54%            90.58%
# 6                 83.98%         94.13%            97.04%            91.33%
# 7                 81.03%         66.68%            81.93%            54.64%
# 8                 83.81%         92.51%            96.25%            89.23%
# 9                 84.04%         94.59%            95.95%            90.54%
# 10                83.95%         93.33%            96.61%            90.33%
# 11                80.74%         66.37%            80.22%            52.99%
# 12                80.97%         66.06%            81.22%            53.54%
# 13                80.75%         68.31%            79.30%            54.29%
# 14                83.85%         93.27%            97.31%            90.95%

# %%
# Determine the maximum budget per student from the scores_by_analysis DataFrame to set the top range for the bins
max_budget_per_student = scores_by_analysis['Per Student Budget'].str.replace('$', '').str.replace(',', '').astype(float).max()
max_budget_per_student
# Out:
# 655.0

# %%
# Create spending range bins and group names for the school spending analysis
spending_bins = [0, 585, 630, 645, 680]
spending_bin_names = ['<$585', '$585-630', '$630-645', '$645-680']

# %%
# create a new DataFrame from the scores_by_analysis DataFrame to hold the scores by spending analysis
spending_analysis = scores_by_analysis[['School Name', 'Per Student Budget', 'Average Math Score', 'Average Reading Score', '% Passing Math', '% Passing Reading', '% Overall Passing']].copy()
spending_analysis
# Out:
#               School Name Per Student Budget Average Math Score  \
# 0       Huang High School            $655.00             76.63%
# 1    Figueroa High School            $639.00             76.71%
# 2     Shelton High School            $600.00             83.36%
# 3   Hernandez High School            $652.00             77.29%
# 4     Griffin High School            $625.00             83.35%
# 5      Wilson High School            $578.00             83.27%
# 6     Cabrera High School            $582.00             83.06%
# 7      Bailey High School            $628.00             77.05%
# 8      Holden High School            $581.00             83.80%
# 9        Pena High School            $609.00             83.84%
# 10     Wright High School            $583.00             83.68%
# 11  Rodriguez High School            $637.00             76.84%
# 12    Johnson High School            $650.00             77.07%
# 13       Ford High School            $644.00             77.10%
# 14     Thomas High School            $638.00             83.42%
#
#    Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                 81.18%         65.68%            81.32%            53.51%
# 1                 81.16%         65.99%            80.74%            53.20%
# 2                 83.73%         93.87%            95.85%            89.89%
# 3                 80.93%         66.75%            80.86%            53.53%
# 4                 83.82%         93.39%            97.14%            90.60%
# 5                 83.99%         93.87%            96.54%            90.58%
# 6                 83.98%         94.13%            97.04%            91.33%
# 7                 81.03%         66.68%            81.93%            54.64%
# 8                 83.81%         92.51%            96.25%            89.23%
# 9                 84.04%         94.59%            95.95%            90.54%
# 10                83.95%         93.33%            96.61%            90.33%
# 11                80.74%         66.37%            80.22%            52.99%
# 12                80.97%         66.06%            81.22%            53.54%
# 13                80.75%         68.31%            79.30%            54.29%
# 14                83.85%         93.27%            97.31%            90.95%

# %%
# Convert the 'Per Student Budget' column back to float data type to use the bins
spending_analysis['Per Student Budget'] = spending_analysis['Per Student Budget'].str.replace('$', '').str.replace(',', '').astype(float)
spending_analysis
# Out:
#               School Name  Per Student Budget Average Math Score  \
# 0       Huang High School               655.0             76.63%
# 1    Figueroa High School               639.0             76.71%
# 2     Shelton High School               600.0             83.36%
# 3   Hernandez High School               652.0             77.29%
# 4     Griffin High School               625.0             83.35%
# 5      Wilson High School               578.0             83.27%
# 6     Cabrera High School               582.0             83.06%
# 7      Bailey High School               628.0             77.05%
# 8      Holden High School               581.0             83.80%
# 9        Pena High School               609.0             83.84%
# 10     Wright High School               583.0             83.68%
# 11  Rodriguez High School               637.0             76.84%
# 12    Johnson High School               650.0             77.07%
# 13       Ford High School               644.0             77.10%
# 14     Thomas High School               638.0             83.42%
#
#    Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                 81.18%         65.68%            81.32%            53.51%
# 1                 81.16%         65.99%            80.74%            53.20%
# 2                 83.73%         93.87%            95.85%            89.89%
# 3                 80.93%         66.75%            80.86%            53.53%
# 4                 83.82%         93.39%            97.14%            90.60%
# 5                 83.99%         93.87%            96.54%            90.58%
# 6                 83.98%         94.13%            97.04%            91.33%
# 7                 81.03%         66.68%            81.93%            54.64%
# 8                 83.81%         92.51%            96.25%            89.23%
# 9                 84.04%         94.59%            95.95%            90.54%
# 10                83.95%         93.33%            96.61%            90.33%
# 11                80.74%         66.37%            80.22%            52.99%
# 12                80.97%         66.06%            81.22%            53.54%
# 13                80.75%         68.31%            79.30%            54.29%
# 14                83.85%         93.27%            97.31%            90.95%

# %%
# Convert test scores and % passing back to numeric values
spending_analysis.loc[:, 'Average Math Score'] = spending_analysis['Average Math Score'].str.replace('%', '').astype(float)
spending_analysis.loc[:, 'Average Reading Score'] = spending_analysis['Average Reading Score'].str.replace('%', '').astype(float)
spending_analysis.loc[:, '% Passing Math'] = spending_analysis['% Passing Math'].str.replace('%', '').astype(float)
spending_analysis.loc[:, '% Passing Reading'] = spending_analysis['% Passing Reading'].str.replace('%', '').astype(float)
spending_analysis.loc[:, '% Overall Passing'] = spending_analysis['% Overall Passing'].str.replace('%', '').astype(float)
spending_analysis
# Out:
#               School Name  Per Student Budget Average Math Score  \
# 0       Huang High School               655.0              76.63
# 1    Figueroa High School               639.0              76.71
# 2     Shelton High School               600.0              83.36
# 3   Hernandez High School               652.0              77.29
# 4     Griffin High School               625.0              83.35
# 5      Wilson High School               578.0              83.27
# 6     Cabrera High School               582.0              83.06
# 7      Bailey High School               628.0              77.05
# 8      Holden High School               581.0               83.8
# 9        Pena High School               609.0              83.84
# 10     Wright High School               583.0              83.68
# 11  Rodriguez High School               637.0              76.84
# 12    Johnson High School               650.0              77.07
# 13       Ford High School               644.0               77.1
# 14     Thomas High School               638.0              83.42
#
#    Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                  81.18          65.68             81.32             53.51
# 1                  81.16          65.99             80.74              53.2
# 2                  83.73          93.87             95.85             89.89
# 3                  80.93          66.75             80.86             53.53
# 4                  83.82          93.39             97.14              90.6
# 5                  83.99          93.87             96.54             90.58
# 6                  83.98          94.13             97.04             91.33
# 7                  81.03          66.68             81.93             54.64
# 8                  83.81          92.51             96.25             89.23
# 9                  84.04          94.59             95.95             90.54
# 10                 83.95          93.33             96.61             90.33
# 11                 80.74          66.37             80.22             52.99
# 12                 80.97          66.06             81.22             53.54
# 13                 80.75          68.31              79.3             54.29
# 14                 83.85          93.27             97.31             90.95

# %%
# Create a new column in the spending_analysis DataFrame to hold the spending bins based on the 'Per Student Budget' column
spending_analysis['Budget Ranges (Per Student)'] = pd.cut(spending_analysis['Per Student Budget'], spending_bins, labels=spending_bin_names)
spending_analysis
# Out:
#               School Name  Per Student Budget Average Math Score  \
# 0       Huang High School               655.0              76.63
# 1    Figueroa High School               639.0              76.71
# 2     Shelton High School               600.0              83.36
# 3   Hernandez High School               652.0              77.29
# 4     Griffin High School               625.0              83.35
# 5      Wilson High School               578.0              83.27
# 6     Cabrera High School               582.0              83.06
# 7      Bailey High School               628.0              77.05
# 8      Holden High School               581.0               83.8
# 9        Pena High School               609.0              83.84
# 10     Wright High School               583.0              83.68
# 11  Rodriguez High School               637.0              76.84
# 12    Johnson High School               650.0              77.07
# 13       Ford High School               644.0               77.1
# 14     Thomas High School               638.0              83.42
#
#    Average Reading Score % Passing Math % Passing Reading % Overall Passing  \
# 0                  81.18          65.68             81.32             53.51
# 1                  81.16          65.99             80.74              53.2
# 2                  83.73          93.87             95.85             89.89
# 3                  80.93          66.75             80.86             53.53
# 4                  83.82          93.39             97.14              90.6
# 5                  83.99          93.87             96.54             90.58
# 6                  83.98          94.13             97.04             91.33
# 7                  81.03          66.68             81.93             54.64
# 8                  83.81          92.51             96.25             89.23
# 9                  84.04          94.59             95.95             90.54
# 10                 83.95          93.33             96.61             90.33
# 11                 80.74          66.37             80.22             52.99
# 12                 80.97          66.06             81.22             53.54
# 13                 80.75          68.31              79.3             54.29
# 14                 83.85          93.27             97.31             90.95
#
#    Budget Ranges (Per Student)
# 0                     $645-680
# 1                     $630-645
# 2                     $585-630
# 3                     $645-680
# 4                     $585-630
# 5                        <$585
# 6                        <$585
# 7                     $585-630
# 8                        <$585
# 9                     $585-630
# 10                       <$585
# 11                    $630-645
# 12                    $645-680
# 13                    $630-645
# 14                    $630-645

# %%
# Move the 'Budget Ranges (Per Student)' column to the second column in the spending_analysis DataFrame and delete Per Student Budget column
spending_analysis = spending_analysis[['School Name', 'Budget Ranges (Per Student)', 'Average Math Score', 'Average Reading Score', '% Passing Math', '% Passing Reading', '% Overall Passing']]
spending_analysis
# Out:
#               School Name Budget Ranges (Per Student) Average Math Score  \
# 0       Huang High School                    $645-680              76.63
# 1    Figueroa High School                    $630-645              76.71
# 2     Shelton High School                    $585-630              83.36
# 3   Hernandez High School                    $645-680              77.29
# 4     Griffin High School                    $585-630              83.35
# 5      Wilson High School                       <$585              83.27
# 6     Cabrera High School                       <$585              83.06
# 7      Bailey High School                    $585-630              77.05
# 8      Holden High School                       <$585               83.8
# 9        Pena High School                    $585-630              83.84
# 10     Wright High School                       <$585              83.68
# 11  Rodriguez High School                    $630-645              76.84
# 12    Johnson High School                    $645-680              77.07
# 13       Ford High School                    $630-645               77.1
# 14     Thomas High School                    $630-645              83.42
#
#    Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                  81.18          65.68             81.32             53.51
# 1                  81.16          65.99             80.74              53.2
# 2                  83.73          93.87             95.85             89.89
# 3                  80.93          66.75             80.86             53.53
# 4                  83.82          93.39             97.14              90.6
# 5                  83.99          93.87             96.54             90.58
# 6                  83.98          94.13             97.04             91.33
# 7                  81.03          66.68             81.93             54.64
# 8                  83.81          92.51             96.25             89.23
# 9                  84.04          94.59             95.95             90.54
# 10                 83.95          93.33             96.61             90.33
# 11                 80.74          66.37             80.22             52.99
# 12                 80.97          66.06             81.22             53.54
# 13                 80.75          68.31              79.3             54.29
# 14                 83.85          93.27             97.31             90.95
